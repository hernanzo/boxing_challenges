# %%
from matplotlib.pyplot import figure
import networkx as nx
from matplotlib.pyplot import figure
import pandas as pd
import matplotlib.pyplot as plt
from csv import reader
import sys 
import numpy as np

# %%
df = pd.read_csv(r'/Users/hernanadasme/Projects/data_challenges/notebooks /challenges_cleaned_corrected.csv')

# %%
df.head()
# Out:
#    challenge_id           rec_Title                          source  \
# 0           972      Araya v. Bolli  Semanario La Prensa. Los Andes
# 1           975     Valdes v. Pérez  Semanario La Prensa. Los Andes
# 2           978      Ortiz v. Araya  Semanario La Prensa. Los Andes
# 3           985  Valdes v. Gallardo  Semanario La Prensa. Los Andes
# 4           986    Silva v. Iñiguez                      Los Sports
#
#   source_year  challenging_id boxer_challenging  challenged_id  \
# 0  1928-04-05             882     Araya, Manuel            780
# 1  1928-04-08             833     Valdes, Mario            272
# 2  1928-04-08             976     Ortiz, Rafael            882
# 3  1928-04-29             833     Valdes, Mario            827
# 4  1924-02-01             189     Silva, Carlos            987
#
#   boxer_challenged    status condition basis  \
# 0    Bolli, Carlos       NaN       NaN   NaN
# 1    Pérez, Amador       NaN       NaN   NaN
# 2    Araya, Manuel       NaN       NaN   NaN
# 3  Gallardo, Pedro       NaN       NaN   NaN
# 4   Iñiguez, Mario  accepted       NaN   NaN
#
#                             location_descp         city  \
# 0  Manager's business, downtown Los Andes.    Los Andes
# 1                                      NaN    Los Andes
# 2                                      NaN    Los Andes
# 3                                      NaN    Los Andes
# 4                                      NaN  Antofagasta
#
#                        location  weight
# 0  POINT(-70.600875 -32.835752)       1
# 1  POINT(-70.688871 -32.833203)       2
# 2  POINT(-70.598582 -32.833016)       2
# 3  POINT(-70.593621 -32.834478)       2
# 4  POINT(-70.397502 -23.650928)       1

# %%
#option D which mixes the from_pandas_edgelist and the adding metadata with a loop
CH = nx.from_pandas_edgelist(df, 'challenging_id', 'challenged_id', edge_attr='weight')
CH.add_nodes_from(df['challenging_id'], bipartite = 'challenger')
CH.add_nodes_from(df['challenged_id'], bipartite = 'challenged')
for box, row in df.iterrows():
    CH.nodes[row['challenging_id']]['name'] = row['boxer_challenging']
    CH.nodes[row['challenged_id']]['name'] = row['boxer_challenged']
    CH.nodes[row['challenging_id']]['source'] = row['source']
    CH.nodes[row['challenging_id']]['date'] = row['source_year']
for r, d in df.iterrows():
    CH.add_edge(d['challenging_id'], d['challenged_id'], date = d['source_year'], challenge = d['rec_Title'])    
# Add the degree centrality score of each node to their metadata dictionary
dcs = nx.degree_centrality(CH)
for n in CH.nodes():
    CH.nodes[n]['centrality'] = dcs[n]
len(CH.nodes), len(CH.edges)
# Out:
# (259, 171)

# %%
CH.nodes(data=True)
# Out:
# NodeDataView({882: {'bipartite': 'challenged', 'name': 'Araya, Manuel', 'source': 'Semanario La Prensa. Los Andes', 'date': '1928-04-05', 'centrality': 0.007751937984496124, 'degree': 2}, 780: {'bipartite': 'challenged', 'name': 'Bolli, Carlos', 'centrality': 0.003875968992248062, 'degree': 1}, 833: {'bipartite': 'challenged', 'name': 'Valdes, Mario', 'source': 'Semanario La Prensa. Los Andes', 'date': '1928-01-01', 'centrality': 0.015503875968992248, 'degree': 4}, 272: {'bipartite': 'challenged', 'name': 'Pérez, Amador', 'centrality': 0.003875968992248062, 'degree': 1}, 976: {'bipartite': 'challenger', 'name': 'Ortiz, Rafael', 'source': 'Semanario La Prensa. Los Andes', 'date': '1928-04-08', 'centrality': 0.003875968992248062, 'degree': 1}, 827: {'bipartite': 'challenged', 'name': 'Gallardo, Pedro', 'centrality': 0.007751937984496124, 'degree': 2}, 189: {'bipartite': 'challenger', 'name': 'Silva, Carlos', 'source': 'Los Sports', 'date': '1924-02-01', 'centrality': 0.003875968992248062, 'degree': 1}, 987: {'bipartite': 'challenged', 'name': 'Iñiguez, Mario', 'centrality': 0.003875968992248062, 'degree': 1}, 302: {'bipartite': 'challenger', 'name': 'Flores, Sara', 'source': 'Los Sports', 'date': '1924-03-07', 'centrality': 0.003875968992248062, 'degree': 1}, 303: {'bipartite': 'challenged', 'name': 'Farrafino, Cleme', 'centrality': 0.003875968992248062, 'degree': 1}, 891: {'bipartite': 'challenger', 'name': 'Huerta, Francisco', 'source': 'Los Sports', 'date': '1924-02-01', 'centrality': 0.003875968992248062, 'degree': 1}, 573: {'bipartite': 'challenged', 'name': 'Giaverini, Oscar', 'centrality': 0.007751937984496124, 'degree': 2}, 158: {'bipartite': 'challenger', 'name': 'Tapia, Julio', 'source': 'Los Sports', 'date': '1924-03-07', 'centrality': 0.003875968992248062, 'degree': 1}, 1001: {'bipartite': 'challenged', 'name': 'Inostroza, Ruperto', 'centrality': 0.003875968992248062, 'degree': 1}, 1003: {'bipartite': 'challenger', 'name': 'Alley, Juan', 'source': 'Los Sports', 'date': '1924-03-07', 'centrality': 0.003875968992248062, 'degree': 1}, 321: {'bipartite': 'challenged', 'name': 'Salinas, Juan', 'centrality': 0.003875968992248062, 'degree': 1}, 647: {'bipartite': 'challenger', 'name': 'Olguín, Humberto', 'source': 'Los Sports', 'date': '1925-11-27', 'centrality': 0.015503875968992248, 'degree': 4}, 423: {'bipartite': 'challenged', 'name': 'Valdenegro', 'centrality': 0.003875968992248062, 'degree': 1}, 1006: {'bipartite': 'challenged', 'name': 'Henriquez', 'centrality': 0.003875968992248062, 'degree': 1}, 1008: {'bipartite': 'challenged', 'name': 'Leiva', 'centrality': 0.003875968992248062, 'degree': 1}, 332: {'bipartite': 'challenger', 'name': 'Acosta, Luis J.', 'source': 'Los Sports', 'date': '1924-03-14', 'centrality': 0.007751937984496124, 'degree': 2}, 1010: {'bipartite': 'challenged', 'name': 'Molina, Erasmo', 'centrality': 0.011627906976744186, 'degree': 3}, 1012: {'bipartite': 'challenged', 'name': 'Parra, Routier', 'source': 'Los Sports', 'date': '1928-07-27', 'centrality': 0.007751937984496124, 'degree': 2}, 502: {'bipartite': 'challenger', 'name': 'Rios, Agustin', 'source': 'Los Sports', 'date': '1924-03-14', 
': 'Parra v. Molina'}), (502, 1014, {'weight': 1, 'date': '1924-03-14', 'challenge': 'Rios v. Arratia'}), (143, 572, {'weight': 1, 'date': '1924-04-04', 'challenge': 'Caldera v. Anguita'}), (77, 146, {'weight': 1, 'date': '1924-01-23', 'challenge': 'Guerrero v. Lasseube'}), (146, 939, {'weight': 1, 'date': '1924-01-23', 'challenge': 'Salinas v. Lasseube'}), (146, 1255, {'weight': 1, 'date': '1927-05-20', 'challenge': 'Lucero v. Lasseube'}), (639, 1021, {'weight': 2, 'date': '1925-03-20', 'challenge': 'Gonzalez v. Suarez'}), (639, 735, {'weight': 1, 'date': '1924-04-15', 'challenge': 'Gonzalez v. Correa'}), (639, 1024, {'weight': 1, 'date': '1924-04-15', 'challenge': 'Gonzalez v. Cipry'}), (639, 1026, {'weight': 1, 'date': '1924-04-15', 'challenge': 'Gonzalez v. Saavedra'}), (639, 156, {'weight': 1, 'date': '1925-03-20', 'challenge': 'Gonzalez v. Duque Rodríguez'}), (639, 420, {'weight': 1, 'date': '1925-03-20', 'challenge': 'Gonzalez v. Murray'}), (639, 935, {'weight': 1, 'date': '1925-07-10', 'challenge': 'Gonzalez v. Ibarra'}), (639, 190, {'weight': 1, 'date': '1921-03-10', 'challenge': 'Gonzalez v. Bastías'}), (1026, 276, {'weight': 1, 'date': '1925-08-07', 'challenge': 'Saavedra v. Férnandez'}), (732, 223, {'weight': 1, 'date': '1924-05-23', 'challenge': 'Villablanca v. Jaña'}), (732, 733, {'weight': 1, 'date': '1924-05-23', 'challenge': 'Villablanca v. Meza'}), (223, 1324, {'weight': 1, 'date': '1923-09-28', 'challenge': 'Navarro v. Jaña'}), (163, 1031, {'weight': 1, 'date': '1924-01-25', 'challenge': 'García v. Valdivieso'}), (162, 1035, {'weight': 1, 'date': '1924-01-25', 'challenge': 'Guerra v. Martinez'}), (175, 98, {'weight': 1, 'date': '1924-01-25', 'challenge': 'Araya v. Mery'}), (174, 1038, {'weight': 1, 'date': '1924-01-25', 'challenge': 'Tapia v. Ibarra'}), (177, 1040, {'weight': 1, 'date': '1924-01-25', 'challenge': 'Fajardo v. Iglesias'}), (178, 126, {'weight': 1, 'date': '1924-01-25', 'challenge': 'Vargas v. Rojas'}), (178, 1253, {'weight': 1, 'date': '1927-05-20', 'challenge': 'Vargas v. Cazzano'}), (178, 62, {'weight': 1, 'date': '1925-08-14', 'challenge': 'Vargas v. Contreras'}), (178, 1080, {'weight': 1, 'date': '1 ...

# %%
# 1. create a bipartite list for boxers challenged and boxers challenging
challengers = [node for node in CH.nodes() if node in df.challenging_id.unique()]
challenged = [node for node in CH.nodes() if node in df.challenged_id.unique()]
print(len(challengers))
print(len(challenged))
# Out:
# 131
# 148

# %%
# 2. Create a layout for our nodes 
pos = nx.spring_layout(CH, k =0.5)
pos["639"] = (0.005,0.005)

# %%
# 3. Size of bipartite nodes according to the degree centrality
size = [CH.degree(node) * 2500 for node in CH.nodes() if node in df.challenging_id.unique()]
size_ed = [CH.degree(node) * 1800 for node in CH.nodes() if node in df.challenged_id.unique()]

# %%
# 4. Creating labels from edge and nodes atributes
edge_labels = nx.get_edge_attributes(CH, 'challenge')
node_labels = nx.get_node_attributes(CH, 'name')

# %%
fig, ax = plt.subplots(figsize=(55, 55), dpi=100)
# 2. Create a layout for our nodes 
pos = nx.nx_agraph.graphviz_layout(CH, prog="twopi")
#pos["639"] = (0.005,0.005)
nx.draw_networkx_edges(CH, pos, edge_color='lightblue', arrows=True, arrowstyle ='-', arrowsize=65, width=4.0)
nx.draw_networkx_nodes(CH, pos, nodelist=challengers, node_size=size, node_color ='#EFC4A1')
nx.draw_networkx_nodes(CH, pos, nodelist=challenged, node_size=size_ed, node_color ='#E18CC4')
challengers_dict = dict(zip(challengers, challengers))
nx.draw_networkx_labels(CH, pos, labels = node_labels, font_size=15)
#nx.draw_networkx_edge_labels(CH, pos, edge_labels = edge_labels, font_size= 10)
#nx.draw_networkx_labels(CH, pos, labels=challenged_dict)
#ax.margins(0.1, 0.05)
#fig.tight_layout()
plt.axis("off")
plt.title('Boxing Challenges - Degree Centrality', fontsize=60)
fig = plt.gcf()
#fig.savefig('figure_9.pdf', dpi=100, format='pdf', bbox_inches='tight') 
fig.savefig('graph_centrality_01.svg', dpi=1200, format='svg', bbox_inches='tight') 
#fig.savefig('figure_9.png', dpi=100, format='png', bbox_inches='tight')
plt.show()

# %%
#Print network summary
print("Network summary: \n-----------------\n", nx.info(CH))
# Out:
# Network summary:
# -----------------
#  Graph with 259 nodes and 171 edges

# %%
#Print network density
print("Network density: \n-----------------\n", nx.density(CH))
# Out:
# Network density:
# -----------------
#  0.005118074885516746

# %%
johnston_path = nx.shortest_path(CH, source= 639, target= 535)

print("Shortest Path: \n-----------------\n", "Shortest path between Johnson Gonzalez and Orlando Sanchez", johnston_path)
# Out:
# Shortest Path:
# -----------------
#  Shortest path between Johnson Gonzalez and Orlando Sanchez [639, 1026, 276, 1138, 535]

# %%
#find number of nodes they are connected with
print("\nNodes Gonzalez, Johnston is connected with :\n-------------------------------")
print(nx.degree(CH, 639))
# Out:
# Nodes Gonzalez, Johnston is connected with :
# -------------------------------
# 8

# %%
#Function to sort a dictionary by value
def sort_dict(dict):
    sorted_dict= sorted(dict.items(), key=lambda x: x[1],reverse=True)
    
    for key,value in sorted_dict:
        print(key, " = ", value)

# %%
#Find centrality of nodes
print("\nCentrality :\n---------------")
sort_dict(nx.degree_centrality(CH))
# Out:
# Centrality :
# ---------------
# 639  =  0.031007751937984496
# 836  =  0.027131782945736434
# 1131  =  0.01937984496124031
# 833  =  0.015503875968992248
# 647  =  0.015503875968992248
# 178  =  0.015503875968992248
# 1414  =  0.015503875968992248
# 1010  =  0.011627906976744186
# 146  =  0.011627906976744186
# 935  =  0.011627906976744186
# 1079  =  0.011627906976744186
# 1261  =  0.011627906976744186
# 1389  =  0.011627906976744186
# 1549  =  0.011627906976744186
# 284  =  0.0
# 1236  =  0.0
# 1321  =  0.0
# 1328  =  0.0
# 1325  =  0.0
# 1326  =  0.0
# 188  =  0.0
# 1332  =  0.0
# 594  =  0.0
# 144  =  0.0
# 1336  =  0.0
# 837  =  0.0
# 866  =  0.0
# 867  =  0.0
# 872  =  0.0
# 875  =  0.0
# 839  =  0.0
# 876  =  0.0
# 873  =  0.0
# 886  =  0.0
# 1352  =  0.0
# 889  =  0.0
# 1355  =  0.0
# 826  =  0.0
# 865  =  0.0
# 1247  =  0.0
# 844  =  0.0
# 1368  =  0.0
# 1369  =  0.0
# 1370  =  0.0
# 190  =  0.0
# 1376  =  0.0
# 1377  =  0.0
# 1381  =  0.0
# 1382  =  0.0
# 1386  =  0.0
# 1388  =  0.0
# 1392  =  0.0
# 1393  =  0.0
# 1397  =  0.0
# 1400  =  0.0
# 1403  =  0.0
# 1402  =  0.0
# 1407  =  0.0
# 1406  =  0.0
# 546  =  0.0
# 1411  =  0.0
# 1417  =  0.0
# 1415  =  0.0
# 1418  =  0.0
# 1425  =  0.0
# 1429  =  0.0
# 1430  =  0.0
# 1434  =  0.0
# 1435  =  0.0
# 1443  =  0.0
# 1442  =  0.0
# 1445  =  0.0
# 1428  =  0.0
# 1449  =  0.0
# 1452  =  0.0
# 1451  =  0.0
# 1455  =  0.0
# 1459  =  0.0
# 1460  =  0.0
# 731  =  0.0
# 1466  =  0.0
# 1471  =  0.0
# 1468  =  0.0
# 1472  =  0.0
# 1475  =  0.0
# 1473  =  0.0
# 1482  =  0.0
# 1481  =  0.0
# 297  =  0.0
# 1484  =  0.0
# 1487  =  0.0
# 1486  =  0.0
# 1489  =  0.0
# 1490  =  0.0
# 1494  =  0.0
# 1499  =  0.0
# 1503  =  0.0
# 1506  =  0.0
# 1508  =  0.0
# 1512  =  0.0
# 1514  =  0.0
# 409  =  0.0
# 1516  =  0.0
# 1536  =  0.0
# 1537  =  0.0
# 1539  =  0.0
# 448  =  0.0
# 1545  =  0.0
# 561  =  0.0
# 983  =  0.0

# %%
# If your Graph has more than one component, this will return False:
print(nx.is_connected(CH))
# Out:
# False

# %%
# Next, use nx.connected_components to get the list of components,
# then use the max() command to find the largest one:
components = nx.connected_components(CH)
largest_component = max(components, key=len)

# %%
# Create a "subgraph" of just the largest component
# Then calculate the diameter of the subgraph, just like you did with density.
#

subgraph = CH.subgraph(largest_component)
diameter = nx.diameter(subgraph)
print("Network diameter of largest component:", diameter)
# Out:
# Network diameter of largest component: 7

# %%
#transitivity - triadic closure
triadic_closure = nx.transitivity(CH)
print("Triadic closure:", triadic_closure)
# Out:
# Triadic closure: 0

# %%
degree_dict = dict(CH.degree(CH.nodes()))
nx.set_node_attributes(CH, degree_dict, 'degree')

# %%
print(CH.nodes[639])
# Out:
# {'bipartite': 'challenger', 'name': 'Gonzalez, Johnston', 'source': 'El Mercurio de Valparaiso', 'date': '1921-03-10', 'centrality': 0.031007751937984496, 'degree': 8}
